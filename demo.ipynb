# %%
import util
import numpy as np

xtrain, xtest, ytrain, ytest = util.load_mnist()
# Out:
# Using TensorFlow backend.

# %%
from util import random_plotter

ans = random_plotter(xtest[100:110], ytest[100:110], model_dirs=[
    'left',
    'gt',
    'models/Unet/unet-80.hdf5',
    'models/GAN/GAN_batch200_diter5/G_27000.hdf5',
], im_w=100, im_h=100, shuffle=True)
# Out:
# "left" prediction done.
# "gt" prediction done.
# "models/Unet/unet-80.hdf5" prediction done.
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
# "models/GAN/GAN_batch200_diter5/G_27000.hdf5" prediction done.
